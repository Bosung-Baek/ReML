# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
#load tensoflow cifar-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(3, (5, 5), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.7959 - accuracy: 0.3566
# Epoch 2/5
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.6030 - accuracy: 0.4347
# Epoch 3/5
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.5335 - accuracy: 0.4599
# Epoch 4/5
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4896 - accuracy: 0.4739
# Epoch 5/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.4505 - accuracy: 0.4836
# 313/313 [==============================] - 2s 4ms/step - loss: 1.4135 - accuracy: 0.5053
# [1.4135364294052124, 0.505299985408783]

# %%
# get wrong x_test predictions
predictions = model.predict(x_test)
for i in range(100):
    print(i)
    print('predicted : ',np.argmax(predictions[i]))
    print('answer : ' ,y_test[i])
plt.imshow(x_test[0], cmap=plt.cm.binary)
# Out:
# 313/313 [==============================] - 2s 4ms/step
# 0
# predicted :  3
# answer :  [3]
# 1
# predicted :  8
# answer :  [8]
# 2
# predicted :  8
# answer :  [8]
# 3
# predicted :  8
# answer :  [0]
# 4
# predicted :  4
# answer :  [6]
# 5
# predicted :  6
# answer :  [6]
# 6
# predicted :  3
# answer :  [1]
# 7
# predicted :  6
# answer :  [6]
# 8
# predicted :  5
# answer :  [3]
# 9
# predicted :  1
# answer :  [1]
# 10
# predicted :  8
# answer :  [0]
# 11
# predicted :  9
# answer :  [9]
# 12
# predicted :  6
# answer :  [5]
# 13
# predicted :  7
# answer :  [7]
# 14
# predicted :  1
# answer :  [9]
# 15
# predicted :  8
# answer :  [8]
# 16
# predicted :  3
# answer :  [5]
# 17
# predicted :  3
# answer :  [7]
# 18
# predicted :  8
# answer :  [8]
# 19
# predicted :  6
# answer :  [6]
# 20
# predicted :  7
# answer :  [7]
# 21
# predicted :  2
# answer :  [0]
# 22
# predicted :  0
# answer :  [4]
# 23
# predicted :  9
# answer :  [9]
# 24
# predicted :  4
# answer :  [5]
# 25
# predicted :  6
# answer :  [2]
# 26
# predicted :  6
# answer :  [4]
# 27
# predicted :  7
# answer :  [0]
# 28
# predicted :  9
# answer :  [9]
# 29
# predicted :  6
# answer :  [6]
# 30
# predicted :  6
# answer :  [6]
# 31
# predicted :  4
# answer :  [5]
# 32
# predicted :  8
# answer :  [4]
# 33
# predicted :  6
# answer :  [5]
# 34
# predicted :  9
# answer :  [9]
# 35
# predicted :  3
# answer :  [2]
# 36
# predicted :  5
# answer :  [4]
# 37
# predicted :  9
# answer :  [1]
# 38
# predicted :  1
# answer :  [9]
# 39
# predicted :  5
# answer :  [5]
# 40
# predicted :  1
# answer :  [4]
# 41
# predicted :  6
# answer :  [6]
# 42
# predicted :  3
# answer :  [5]
# 43
# predicted :  6
# answer :  [6]
# 44
# predicted :  0
# answer :  [0]
# 45
# predicted :  9
# answer :  [9]
# 46
# predicted :  3
# answer :  [3]
# 47
# predicted :  9
# answer :  [9]
# 48
# predicted :  4
# answer :  [7]
# 49
# predicted :  4
# answer :  [6]
# 50
# predicted :  9
# answer :  [9]
# 51
# predicted :  8
# answer :  [8]
# 52
# predicted :  6
# answer :  [0]
# 53
# predicted :  3
# answer :  [3]
# 54
# predicted :  8
# answer :  [8]
# 55
# predicted :  8
# answer :  [8]
# 56
# predicted :  5
# answer :  [7]
# 57
# predicted :  9
# answer :  [7]
# 58
# predicted :  2
# answer :  [4]
# 59
# predicted :  3
# answer :  [6]
# 60
# predicted :  7
# answer :  [7]
# 61
# predicted :  6
# answer :  [3]
# 62
# predicted :  4
# answer :  [6]
# 63
# predicted :  5
# answer :  [3]
# 64
# predicted :  6
# answer :  [6]
# 65
# predicted :  3
# answer :  [2]
# 66
# predicted :  1
# answer :  [1]
# 67
# predicted :  8
# answer :  [2]
# 68
# predicted :  5
# answer :  [3]
# 69
# predicted :  9
# answer :  [7]
# 70
# predicted :  4
# answer :  [2]
# 71
# predicted :  6
# answer :  [6]
# 72
# predicted :  8
# answer :  [8]
# 73
# predicted :  8
# answer :  [8]
# 74
# predicted :  8
# answer :  [0]
# 75
# predicted :  4
# answer :  [2]
# 76
# predicted :  9
# answer :  [9]
# 77
# predicted :  3
# answer :  [3]
# 78
# predicted :  6
# answer :  [3]
# 79
# predicted :  8
# answer :  [8]
# 80
# predicted :  8
# answer :  [8]
# 81
# predicted :  1
# answer :  [1]
# 82
# predicted :  1
# answer :  [1]
# 83
# predicted :  7
# answer :  [7]
# 84
# predicted :  2
# answer :  [2]
# 85
# predicted :  7
# answer :  [5]
# 86
# predicted :  3
# answer :  [2]
# 87
# predicted :  8
# answer :  [7]
# 88
# predicted :  8
# answer :  [8]
# 89
# predicted :  9
# answer :  [9]
# 90
# predicted :  0
# answer :  [0]
# 91
# predicted :  4
# answer :  [3]
# 92
# predicted :  8
# answer :  [8]
# 93
# predicted :  6
# answer :  [6]
# 94
# predicted :  4
# answer :  [4]
# 95
# predicted :  5
# answer :  [6]
# 96
# predicted :  6
# answer :  [6]
# 97
# predicted :  8
# answer :  [0]
# 98
# predicted :  0
# answer :  [0]
# 99
# predicted :  7
# answer :  [7]

# %%
new_predictions = predictions.argmax(axis = 1)
answer_sheet = new_predictions == y_test
for i in range(len(answer_sheet)):
    if answer_sheet[i] == False:
        plt.imshow(x_test[i], cmap=plt.cm.binary)
        plt.show()
        print('predicted : ',np.argmax(predictions[i]))
        print('weight : ', np.round(predictions[i],2))
        print('answer : ' ,y_test[i])
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\bosung\ReML\.vscode\tensoflow5.ipynb 셀 7 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/bosung/ReML/.vscode/tensoflow5.ipynb#ch0000006?line=1'>2</a> answer_sheet = new_predictions == y_test
#       <a href='vscode-notebook-cell:/c%3A/Users/bosung/ReML/.vscode/tensoflow5.ipynb#ch0000006?line=2'>3</a> for i in range(len(answer_sheet)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bosung/ReML/.vscode/tensoflow5.ipynb#ch0000006?line=3'>4</a>     if answer_sheet[i] == False:
#       <a href='vscode-notebook-cell:/c%3A/Users/bosung/ReML/.vscode/tensoflow5.ipynb#ch0000006?line=4'>5</a>         plt.imshow(x_test[i], cmap=plt.cm.binary)
#       <a href='vscode-notebook-cell:/c%3A/Users/bosung/ReML/.vscode/tensoflow5.ipynb#ch0000006?line=5'>6</a>         plt.show()
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
